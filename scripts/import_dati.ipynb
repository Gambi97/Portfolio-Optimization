# %%
import numpy as np
import pandas as pd

# %%
#creo una colonna con valori casuali 
colonna = pd.Series(np.random.random(5), name="colonna 1")
colonna
# Out:
# 0    0.671041
# 1    0.739983
# 2    0.911893
# 3    0.006502
# 4    0.487203
# Name: colonna 1, dtype: float64

# %%
#acceso a una riga precisa
colonna[2]
# Out:
# 0.9118931543166028

# %%
from pandas_datareader import data as wb

# %%
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2009-01-02   62.970001   61.060001   61.689999   62.799999  11135700.0
# 2009-01-05   62.439999   61.590000   62.320000   62.349998  14322800.0
# 2009-01-06   62.950001   61.509998   62.500000   62.169998  13401600.0
# 2009-01-07   61.660000   60.639999   61.330002   61.080002  12415600.0
# 2009-01-08   61.250000   60.000000   60.910000   60.410000  11508100.0
# 2009-01-09   60.799999   59.750000   60.639999   59.860001  10843200.0
# 2009-01-12   60.419998   59.689999   59.750000   59.939999  11373200.0
# 2009-01-13   60.290001   59.020000   59.959999   59.470001  15791900.0
# 2009-01-14   59.180000   57.220001   59.049999   57.860001  16108100.0
# 2009-01-15   57.480000   56.549999   57.090000   57.459999  18807200.0
# 2009-01-16   58.250000   57.119999   58.080002   57.730000  18904200.0
# 2009-01-20   58.450001   57.230000   57.770000   57.430000  17999300.0
# ...

# %%
PG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2601 entries, 2009-01-02 to 2019-05-03
# Data columns (total 6 columns):
# High         2601 non-null float64
# Low          2601 non-null float64
# Open         2601 non-null float64
# Close        2601 non-null float64
# Volume       2601 non-null float64
# Adj Close    2601 non-null float64
# dtypes: float64(6)
# memory usage: 142.2 KB

# %%
import pandas as pd
tickers= ['PG', 'MSFT', 'AAPL', 'T']
new_data = pd.DataFrame()
for t in tickers:
    new_data[t] = wb.DataReader(t, data_source='iex', start='2017-1-1')['close']

new_data
# Out:
#                   PG      MSFT      AAPL        T
# date
# 2017-01-03   77.7003   59.9156  112.1398  37.4510
# 2017-01-04   77.9771   59.6476  112.0143  37.2334
# 2017-01-05   78.4939   59.6476  112.5839  37.1289
# 2017-01-06   78.4662   60.1646  113.8391  36.3891
# 2017-01-09   77.8848   59.9731  114.8818  35.9312
# 2017-01-10   77.0451   59.9539  114.9976  35.9400
# 2017-01-11   77.2850   60.4997  115.6155  35.7639
# 2017-01-12   77.3681   59.9444  115.1328  36.1161
# 2017-01-13   77.5249   60.0305  114.9300  36.0721
# 2017-01-17   78.6323   59.8678  115.8569  36.2042
# 2017-01-18   78.9946   59.8390  115.8472  35.9312
# 2017-01-19   78.7807   59.6476  115.6445  36.1073
# 2017-01-20   81.3385   60.0688  115.8569  36.5036
# 2017-01-23   80.8827   60.2795  115.9341  36.9880
# 2017-01-24   81.7198   60.8156  115.8279  36.4244
# 2017-01-25   81.0687   60.9688  117.6720  36.4508
# 2017-01-26   80.5479   61.5337  117.7299  36.7854
# 2017-01-27   80.6595   62.9794  117.7396  36.9968
# ...
